# %%
import yaml
from pipeline_code.core import load_all_visits
# %load_ext autoreload
# %autoreload 2

# %%
# 1. Open and load your YAML file
with open("set_inputs.yaml", "r") as f:
    config = yaml.safe_load(f)

# 2. Pass the loaded config directly into your manager function
# This now uses the real paths and settings defined in your YAML
visits = load_all_visits(config)

# 3. Access your data as usual
print(f"Loaded {len(visits)} visits.")
print(f"First visit white flux: {visits[0].white_flux}")
# Out:
# Loaded 3 visits.
# First visit white flux: [1.00879352 1.00985573 1.01019003 1.0116126  1.01047469 1.0114109
#  1.01109722 1.01185595 1.01108429 1.01121113 1.01035456 1.01039752
#  1.00952972 1.00996202 1.00702976 1.00814867 1.00634683 1.00639878
#  1.00504421 1.00502591 1.00174739 1.00116015 0.99991454 1.0011285
#  0.99924136 0.99826346 0.99633674 0.99729287 0.99610153 0.9963349
#  0.99528509 0.99629347 0.99516376 0.99526245 0.99490256 0.9953203
#  0.99468317 0.99600761 0.99539115 0.99565694 0.99505624 0.99556481
#  0.99562568 0.99694641 0.99646473 0.99786939 0.99694633 0.99811787
#  0.99763904 0.99830727 0.99804674 0.99899149 0.99801722 0.99992444
#  0.99829976 1.00007556 0.99988141 1.00111539 0.99937938 1.00099502
#  1.00066435 1.00198204 1.0013191  1.00157378 1.00303076 1.00297583
#  1.00324818 1.00577652]
